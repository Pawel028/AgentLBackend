# %%
import os
import dotenv
dotenv.load_dotenv()
os.getcwd()
os.chdir('C:\\Users\\Pawel Sogra\\Desktop\\Work\\AgentLawyer\\Backend')
os.getcwd()
# Out:
# 'C:\\Users\\Pawel Sogra\\Desktop\\Work\\AgentLawyer\\Backend'

# %%
api_key = os.getenv("google_api_key")
cse_id = os.getenv("cse_id")
print(f"Google API Key: {api_key}")
# Out:
# Google API Key: AIzaSyA-2pIn5Q8lWfxj6Sx5ZQ2CnmUjZ5tIbLQ

# %%
import requests
query = "what was the case of brutal rape and murder in New delhi in 2012?"
def google_search(query, api_key, cse_id, num_results=5):
    url = f"https://www.googleapis.com/customsearch/v1"
    params = {
        'key': api_key,
        'cx': cse_id,
        'q': query,
        'num': num_results
    }
    
    response = requests.get(url, params=params)
    return response.json()
response = google_search(query=query,api_key=api_key, cse_id=cse_id,num_results=2)

# %%
response['items'][1]['link']
# Out:
# 'https://www.bbc.com/news/world-asia-india-51969961'

# %%
from bs4 import BeautifulSoup
def get_response_link(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    return soup.renderContents()

link_res = get_response_link(response['items'][0]['link'])
# Out:
# C:\Users\Pawel Sogra\AppData\Local\Temp\ipykernel_5268\1037828219.py:5: DeprecationWarning: Call to deprecated method renderContents. (Replaced by encode_contents) -- Deprecated since version 4.0.0.
#   return soup.renderContents()

# %%
list_links = [response['items'][i]['link'] for i in range(len(response['items']))]

# %%
from utilities.backend.webscraping import scrape_multiple_sites
scraped_results = scrape_multiple_sites(list_links)
# Out:
# 🔍 Scraping: https://en.wikipedia.org/wiki/2012_Delhi_gang_rape_and_murder
# 🔍 Scraping: https://www.bbc.com/news/world-asia-india-51969961

# %%
scraped_results[0]['paragraphs']
# Out:
# ['The 2012 Delhi gang rape and murder, commonly known as the Nirbhaya case, involved the gang rape and fatal assault that occurred on 16 December 2012 in Munirka, a neighbourhood in South Delhi. The incident took place when Jyoti Singh, a 22-year-old physiotherapy intern, was beaten, gang-raped, and tortured in a private bus in which she was travelling with her friend, Avnindra Pratap Pandey. There were six others in the bus, including the driver, all of whom raped the woman and beat her friend. She was rushed to Safdarjung Hospital in Delhi for treatment and, as the public outrage mounted, the government had her transferred to Mount Elizabeth Hospital, Singapore eleven days after the assault, where she died from her injuries two days later.[3][4][5] The incident generated widespread national and international coverage and was widely condemned, both in India and abroad. Subsequently, public protests against the state and central governments for failing to provide adequate security fo
# ...
